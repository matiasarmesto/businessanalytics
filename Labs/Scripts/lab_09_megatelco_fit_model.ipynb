# %% [markdown]
# # IS 4487 Lab 9
#
# ## Outline
#
# a. Understand model accuracy.  Why is it a performance metric for classification and not regression?
#
# b. Calculate accuracy for a simple majority class model (this is the same as calculating the proportion of the majority class in a binary variable). Consider: x <- c(1, 1, 1, 0, 0).  What is the majority class? What is the proportion of the majority class in x?
#
# c. Fit a tree model of the target with just two predictor variables and calculate the accuracy of this model.
#
# d. Interpret a tree model, and calculate information gain.
#
# e. Fit a tree model of the target using all the predictors, then:  create a visualization of the tree and identify the top 3 most important predictors in this model.
#
# f. How do these models compare to majority class prediction?
#
# g. How will you use a classification model as part of a solution to the AdviseInvest case?
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Labs/Scripts/lab_09_megatelco_fit_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Megatelco Data Dictionary
#
#  DEMOGRAPHIC VARIABLES:
#  - College - has the customer attended some college (one, zero)
#  - Income - annual income of customer
#  - House - estimated price of the customer's home (if applicable)
#
#  USAGE VARIABLES:
#  - Data Overage Mb - Average number of megabytes that the customer used in excess of the plan limit (over last 12 months)
#  - Data Leftover Mb - Average number of megabytes that the customer use was below the plan limit (over last 12 months)
#  - Data Mb Used - Average number of megabytes used per month (over last 12 months)
#  - Text Message Count - Average number of texts per month (over last 12 months)
#  - Over 15 Minute Calls Per Month - Average number of calls over 15 minutes in duration per month (over last 12 months)
#  - Average Call Duration- Average call duration (over last 12 months)
#
# PHONE VARIABLES:
#  - Operating System - Current operating system of phone
#  - Handset Price - Retail price of the phone used by the customer
#
# ATTITUDINAL VARIABLES:
#  - Reported Satisfaction - Survey response to "How satisfied are you with your current phone plan?" (high, med, low)
#  - Reported Usage Level - Survey response to "How much do your use your phone?" (high, med, low)
#  - Considering Change of Plan - Survey response to "Are you currently planning to change companies when your contract expires?" (high, med, low)
#
# OTHER VARIABLES
#  - Leave - Did this customer churn with the last contract expiration? (LEAVE, STAY)
#  - ID - Customer identifier

# %% [markdown]
# ##Load Libraries
#
# In this class we will be using
# - Pandas
# - Scikitlearn
# - Matplotlib

# %%
import pandas as pd
import matplotlib as mpl
import numpy as np

from sklearn.tree import DecisionTreeClassifier, export_graphviz # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn import tree

# %% [markdown]
# ## Import Data into Dataframe
#
# ➡️ Assignment Tasks
# - Import data from the Megatelco dataset into a dataframe (in GitHub go to Labs > DataSets)
# - Describe or profile the dataframe

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Stan-Pugsley/is_4487_base/main/Labs/DataSets/megatelco_leave_survey.csv')
df.head()
# Out:
#   college  income  data_overage_mb  data_leftover_mb  data_mb_used  \
# 0     one  403137               70                 0          6605
# 1    zero  129700               67                16          6028
# 2    zero   69741               60                 0          1482
# 3     one  377572                0                22          3005
# 4    zero  382080                0                 0          1794
#
#    text_message_count   house  handset_price  over_15mins_calls_per_month  \
# 0                 199  841317            653                          5.0
# 1                 134  476664           1193                          5.0
# 2                 176  810225           1037                          3.0
# 3                 184  826967           1161                          0.0
# 4                  74  951896           1023                          0.0
#
#    average_call_duration reported_satisfaction reported_usage_level  \
# 0                      8                   low                  low
# 1                      5                   low                  low
# 2                      8                   low                  low
# 3                      5                   low                  low
# 4                     14                   low                  low
#
#   considering_change_of_plan  leave     id operating_system
# 0                        yes  LEAVE   8183          Android
# 1                        yes  LEAVE  12501              IOS
# 2                        yes   STAY   7425              IOS
# 3                         no  LEAVE  13488              IOS
# 4                        yes   STAY  11389              IOS

# %% [markdown]
# ## Clean up the data
# Did you notice anything unusual about the "house" amounts?
#
# How about the handset price and income?
#
# Clean up the data in a  new datafram named "df_clean"

# %%
#delete rows with outlier data; put it in a new dataframe
df_clean = df[(df['house'] > 0) & (df['income'] > 0) & (df['handset_price'] < 10000)]

#delete any rows with missing values in the clean dataframe
df_clean = df_clean.dropna()

df_clean.describe()
# Out:
#               income  data_overage_mb  data_leftover_mb  data_mb_used  \
# count   14990.000000     14990.000000      14990.000000  14990.000000
# mean   242051.833689       153.593996         37.526217   4203.088192
# std    109550.800640       112.996435         28.043476   2202.621977
# min     52491.000000         0.000000          0.000000    400.000000
# 25%    147917.250000        54.000000         12.000000   2297.250000
# 50%    241663.000000       151.000000         35.000000   4224.500000
# 75%    336483.500000       242.000000         62.000000   6080.000000
# max    432000.000000       380.000000         89.000000   8000.000000
#
#        text_message_count         house  handset_price  \
# count        14990.000000  1.499000e+04   14990.000000
# mean           135.629286  8.772144e+05     780.669446
# std             48.837706  2.869092e+05     326.560845
# min             52.000000  3.200010e+05     215.000000
# 25%             93.000000  6.446280e+05     498.000000
# 50%            135.000000  8.764390e+05     778.000000
# 75%            178.000000  1.098814e+06    1063.750000
# max            220.000000  1.456389e+06    1350.000000
#
#        over_15mins_calls_per_month  average_call_duration            id
# count                 14990.000000           14990.000000  14990.000000
# mean                     10.571181               9.734556  11862.245430
# std                       8.401508               5.194135   6812.720757
# min                       0.000000               1.000000      2.000000
# 25%                       3.000000               5.000000   6139.500000
# 50%                       9.000000              10.000000  11763.500000
# 75%                      17.000000              14.000000  17398.000000
# max                      35.000000              19.000000  25354.000000

# %% [markdown]
# # Standardize attributes
#
# - Convert the "college" and "considering_change_of_plan" attributes to 0 or 1
# - Convert non-numeric attributes to numeric scale of 1-3

# %%
#Get distinct values
df_clean['college'].unique()
# Out:
# array(['one', 'zero'], dtype=object)

# %%
df_clean['reported_satisfaction'] .unique()
# Out:
# array(['low', 'high', 'avg'], dtype=object)

# %%
df_clean['reported_usage_level'].unique()
# Out:
# array(['low', 'high', 'avg'], dtype=object)

# %%
df_clean['considering_change_of_plan'].unique()
# Out:
# array(['yes', 'no', 'maybe'], dtype=object)

# %%
df_clean.loc[df_clean['college'] == 'one', 'college'] = "1"
df_clean.loc[df_clean['college'] == 'zero', 'college'] = "0"
df_clean.loc[df_clean['reported_satisfaction'] == 'low', 'reported_satisfaction'] = "1"
df_clean.loc[df_clean['reported_satisfaction'] == 'avg', 'reported_satisfaction'] = "2"
df_clean.loc[df_clean['reported_satisfaction'] == 'high', 'reported_satisfaction'] = "3"
df_clean.loc[df_clean['reported_usage_level'] == 'low', 'reported_usage_level'] = "1"
df_clean.loc[df_clean['reported_usage_level'] == 'avg', 'reported_usage_level'] = "2"
df_clean.loc[df_clean['reported_usage_level'] == 'high', 'reported_usage_level'] = "3"
df_clean.loc[df_clean['considering_change_of_plan'] == 'yes', 'considering_change_of_plan'] = "1"
df_clean.loc[df_clean['considering_change_of_plan'] == 'no', 'considering_change_of_plan'] = "0"
df_clean.loc[df_clean['considering_change_of_plan'] == 'maybe', 'considering_change_of_plan'] = "0.5"

df_clean.head(10)
# Out:
#   college  income  data_overage_mb  data_leftover_mb  data_mb_used  \
# 0       1  403137               70                 0          6605
# 1       0  129700               67                16          6028
# 2       0   69741               60                 0          1482
# 3       1  377572                0                22          3005
# 4       0  382080                0                 0          1794
# 5       0  309746                0                56          2675
# 6       1  325592               79                24          7300
# 7       1  131230                0                 0          4489
# 8       1  193667                0                 0          1023
# 9       1  419573                0                74          4631
#
#    text_message_count    house  handset_price  over_15mins_calls_per_month  \
# 0                 199   841317            653                          5.0
# 1                 134   476664           1193                          5.0
# 2                 176   810225           1037                          3.0
# 3                 184   826967           1161                          0.0
# 4                  74   951896           1023                          0.0
# 5                  81  1272862           1200                          5.0
# 6                 190   472330           1083                          5.0
# 7                  89   613744            365                          5.0
# 8                  76   949829            347                          1.0
# 9                 209   818027            640                          0.0
#
#    average_call_duration reported_satisfaction reported_usage_level  \
# 0                      8                     1                    1
# 1                      5                     1                    1
# 2                      8                     1                    1
# 3                      5                     1                    1
# 4                     14                     1                    1
# 5                      1                     1                    3
# 6                      6                     1                    2
# 7                     10                     1                    3
# 8                      8                     3                    1
# 9                      2                     1                    1
#
#   considering_change_of_plan  leave     id operating_system
# 0                          1  LEAVE   8183          Android
# 1                          1  LEAVE  12501              IOS
# 2                          1   STAY   7425              IOS
# 3                          0  LEAVE  13488              IOS
# 4                          1   STAY  11389              IOS
# 5                          1   STAY  14674              IOS
# 6                          1  LEAVE  19100              IOS
# 7                          1   STAY  18170          Android
# 8                          0  LEAVE   3201          Android
# 9                          1  LEAVE  12612          Android

# %% [markdown]
# # Convert attributes to categories
#
# - Leave
# - College
# - Reported satisfaction
# - Reported usage level
# - Considering change of plan

# %%
#Method #1
#df_clean['leave'] = pd.Categorical(df_clean['leave'])

#Method #2
df_clean['leave'] = df_clean['leave'].astype('category')
df_clean['college'] = df_clean['college'].astype('category')
df_clean['reported_satisfaction'] = df_clean['reported_satisfaction'].astype('category')
df_clean['reported_usage_level'] = df_clean['reported_usage_level'].astype('category')
df_clean['considering_change_of_plan'] = df_clean['considering_change_of_plan'].astype('category')

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14990 entries, 0 to 14998
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   college                      14990 non-null  category
#  1   income                       14990 non-null  int64
#  2   data_overage_mb              14990 non-null  int64
#  3   data_leftover_mb             14990 non-null  int64
#  4   data_mb_used                 14990 non-null  int64
#  5   text_message_count           14990 non-null  int64
#  6   house                        14990 non-null  int64
#  7   handset_price                14990 non-null  int64
#  8   over_15mins_calls_per_month  14990 non-null  float64
#  9   average_call_duration        14990 non-null  int64
#  10  reported_satisfaction        14990 non-null  category
#  11  reported_usage_level         14990 non-null  category
#  12  considering_change_of_plan   14990 non-null  category
#  13  leave                        14990 non-null  category
#  14  id                           14990 non-null  int64
#  15  operating_system             14990 non-null  object
# dtypes: category(5), float64(1), int64(9), object(1)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Calculate distribution of the outcome
# What is the proportion of people who churned?
#
# Why should we care about this proportion?
#
# 1. An important step in EDA is to understand the distribution of the target variable.
#
# 2. The majority class in the target variable will serve as an important benchmark for model performance. If we used what we'll call a "majority class classifier"---this consists in always predicting the majority class, which in this case is `STAY`---we would be correct 1 - .49 or 51% of the time.  Another way of saying this is that majority class classifier in the MegaTelCo case would result in accuracy of .51.
#
# Accuracy is defined as the proportion of correctly predicted labels. It is a commonly used error metric for evaluating classifier performance.
#
# Think about why a majority class model in this case would have an accuracy of .51.
#
# Whatever later model we develop should have better accuracy than this performance benchmark.

# %%
#Add new field with binary value for leave
df_clean['leave_flag'] = df_clean['leave'].str.replace('STAY','0')
df_clean['leave_flag'] = df_clean['leave_flag'].str.replace('LEAVE','1')

#Convert to integer
df_clean['leave_flag'] = df_clean['leave_flag'].astype('int')

#Find the mean value
df_clean['leave_flag'].mean()
# Out:
# 0.4982655103402268

# %% [markdown]
# ## Fit a basic tree model
#
# Use just two variables, 'income' and 'house'. We'll call this the "money tree."
#
# What is the accuracy of the money tree?

# %%
# split the datafram into independent (x) and dependent (predicted) attributes (y)
x = df_clean[['income','house']]
y = df_clean['leave']

money_tree = DecisionTreeClassifier()

# Create Decision Tree Classifer
money_tree = money_tree.fit(x,y)

# %% [markdown]
# ## Preview the tree

# %%
money_tree_text = tree.export_text(money_tree)
print(money_tree_text)
# Out:
# |--- feature_1 <= 1200025.00
# |   |--- feature_1 <= 534467.00
# |   |   |--- class: LEAVE
# |   |--- feature_1 >  534467.00
# |   |   |--- feature_0 <= 329219.50
# |   |   |   |--- feature_0 <= 326170.50
# |   |   |   |   |--- feature_1 <= 1180154.50
# |   |   |   |   |   |--- feature_0 <= 266701.00
# |   |   |   |   |   |   |--- feature_0 <= 259224.50
# |   |   |   |   |   |   |   |--- feature_0 <= 55673.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 54109.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1127939.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 778451.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  778451.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1127939.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1173610.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  1173610.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_0 >  54109.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1090106.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1006066.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  1006066.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1090106.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- feature_0 >  55673.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 78210.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 72026.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 70971.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 27
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  70971.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  72026.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 72500.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  72500.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |--- feature_0 >  78210.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 185253.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 184400.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 49
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  184400.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  185253.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 185509.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  185509.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 51
# |   |   |   |   |   |   |--- feature_0 >  259224.50
# |   |   |   |   |   |   |   |--- feature_1 <= 543477.50
# |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- feature_1 >  543477.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1173950.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 559885.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 550541.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  550541.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  559885.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 569294.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  569294.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |--- feature_1 >  1173950.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |--- feature_0 >  266701.00
# |   |   |   |   |   |   |--- feature_0 <= 319931.50
# |   |   |   |   |   |   |   |--- feature_0 <= 267001.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 659839.00
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- feature_1 >  659839.00
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- feature_0 >  267001.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 267184.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 643406.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  643406.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- feature_0 >  267184.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 267880.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 803368.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  803368.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  267880.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 544891.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  544891.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 36
# |   |   |   |   |   |   |--- feature_0 >  319931.50
# |   |   |   |   |   |   |   |--- feature_0 <= 321019.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 948069.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 666129.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 320152.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  320152.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  666129.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 320911.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  320911.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- feature_1 >  948069.00
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- feature_0 >  321019.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1119513.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 321378.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 965979.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  965979.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  321378.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 326074.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  326074.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- feature_1 >  1119513.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 322586.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  322586.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 323702.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  323702.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |--- feature_1 >  1180154.50
# |   |   |   |   |   |--- feature_0 <= 106672.00
# |   |   |   |   |   |   |--- feature_0 <= 53734.50
# |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |--- feature_0 >  53734.50
# |   |   |   |   |   |   |   |--- feature_1 <= 1190174.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1189090.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1181638.00
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1181638.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1187361.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  1187361.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_1 >  1189090.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- feature_1 >  1190174.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1199571.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1194702.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1194199.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  1194199.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1194702.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- feature_1 >  1199571.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |--- feature_0 >  106672.00
# |   |   |   |   |   |   |--- feature_1 <= 1190377.00
# |   |   |   |   |   |   |   |--- feature_0 <= 125381.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1183653.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 112904.00
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  112904.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 122230.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  122230.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- feature_1 >  1183653.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1189462.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1189462.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- feature_0 >  125381.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 278327.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1189683.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 250343.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  250343.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1189683.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- feature_0 >  278327.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 303158.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  303158.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 315410.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  315410.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |--- feature_1 >  1190377.00
# |   |   |   |   |   |   |   |--- feature_1 <= 1195741.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 117331.00
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- feature_0 >  117331.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 156856.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 123197.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  123197.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  156856.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 199960.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  199960.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |--- feature_1 >  1195741.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 229357.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 189938.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1196475.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  1196475.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  189938.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1198121.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  1198121.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_0 >  229357.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1198036.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1198036.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 300527.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  300527.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |--- feature_0 >  326170.50
# |   |   |   |   |--- feature_0 <= 328085.00
# |   |   |   |   |   |--- feature_1 <= 981711.50
# |   |   |   |   |   |   |--- feature_1 <= 950193.50
# |   |   |   |   |   |   |   |--- feature_0 <= 326644.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 326318.00
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- feature_0 >  326318.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 326389.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  326389.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 848253.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  848253.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- feature_0 >  326644.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 327424.00
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- feature_0 >  327424.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 327498.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  327498.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 327884.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  327884.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_1 >  950193.50
# |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |--- feature_1 >  981711.50
# |   |   |   |   |   |   |--- feature_1 <= 1107821.50
# |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |--- feature_1 >  1107821.50
# |   |   |   |   |   |   |   |--- feature_1 <= 1126843.50
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- feature_1 >  1126843.50
# |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |--- feature_0 >  328085.00
# |   |   |   |   |   |--- feature_1 <= 614519.00
# |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |--- feature_1 >  614519.00
# |   |   |   |   |   |   |--- feature_0 <= 328124.00
# |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |--- feature_0 >  328124.00
# |   |   |   |   |   |   |   |--- feature_1 <= 1173948.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 329104.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 329096.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 809847.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  809847.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  329096.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- feature_0 >  329104.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- feature_1 >  1173948.00
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |--- feature_0 >  329219.50
# |   |   |   |--- feature_0 <= 330349.00
# |   |   |   |   |--- feature_1 <= 766046.00
# |   |   |   |   |   |--- class: STAY
# |   |   |   |   |--- feature_1 >  766046.00
# |   |   |   |   |   |--- feature_1 <= 1145645.00
# |   |   |   |   |   |   |--- feature_0 <= 329781.00
# |   |   |   |   |   |   |   |--- feature_0 <= 329627.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 329352.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- feature_0 >  329352.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 900507.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 329532.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  329532.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  900507.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- feature_0 >  329627.50
# |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |--- feature_0 >  329781.00
# |   |   |   |   |   |   |   |--- feature_1 <= 890375.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 876944.50
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- feature_1 >  876944.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |--- feature_1 >  890375.00
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |--- feature_1 >  1145645.00
# |   |   |   |   |   |   |--- feature_0 <= 329498.00
# |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |--- feature_0 >  329498.00
# |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |--- feature_0 >  330349.00
# |   |   |   |   |--- feature_0 <= 331188.50
# |   |   |   |   |   |--- feature_1 <= 764243.50
# |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |--- feature_1 >  764243.50
# |   |   |   |   |   |   |--- feature_1 <= 1019055.00
# |   |   |   |   |   |   |   |--- feature_0 <= 330622.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 330446.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 330416.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  330416.00
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- feature_0 >  330446.00
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- feature_0 >  330622.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 330793.00
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- feature_0 >  330793.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 330915.50
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  330915.50
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |--- feature_1 >  1019055.00
# |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |--- feature_0 >  331188.50
# |   |   |   |   |   |--- feature_0 <= 332061.50
# |   |   |   |   |   |   |--- feature_0 <= 331631.00
# |   |   |   |   |   |   |   |--- feature_0 <= 331309.50
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- feature_0 >  331309.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 564871.50
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |--- feature_1 >  564871.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 768242.00
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  768242.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 889154.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  889154.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_0 >  331631.00
# |   |   |   |   |   |   |   |--- feature_1 <= 1017810.00
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- feature_1 >  1017810.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1150523.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |--- feature_1 >  1150523.50
# |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |--- feature_0 >  332061.50
# |   |   |   |   |   |   |--- feature_0 <= 333296.00
# |   |   |   |   |   |   |   |--- feature_1 <= 545375.50
# |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |--- feature_1 >  545375.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 332920.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 624652.00
# |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  624652.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 751076.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  751076.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- feature_0 >  332920.50
# |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |--- feature_0 >  333296.00
# |   |   |   |   |   |   |   |--- feature_0 <= 343234.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 337107.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1066811.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 750741.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  750741.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1066811.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 333827.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  333827.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_0 >  337107.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 338825.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 576845.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  576845.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  338825.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 338979.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  338979.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |--- feature_0 >  343234.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 353535.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 681915.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 642220.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  642220.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  681915.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 701060.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: LEAVE
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  701060.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 24
# |   |   |   |   |   |   |   |   |--- feature_0 >  353535.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 353686.00
# |   |   |   |   |   |   |   |   |   |   |--- class: STAY
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  353686.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 421148.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 45
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  421148.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 21
# |--- feature_1 >  1200025.00
# |   |--- class: STAY

# %% [markdown]
# ## Check Accuracy
#
# What is the accuracy of the money_tree? Use these steps to calculate accuracy.
#
# Is this over fitted?

# %%
pred = money_tree.predict(x)

#print(pred)

print("Accuracy:",metrics.accuracy_score(y, pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# ## Prune the tree
#
# Limit the number of levels to 2

# %%
money_tree2 = DecisionTreeClassifier(criterion="entropy", max_depth=2)

# Create Decision Tree Classifer
money_tree2 = money_tree2.fit(x,y)

# %% [markdown]
# ## Preview the new tree

# %%
money_tree2_text = tree.export_text(money_tree2)
print(money_tree2_text)
# Out:
# |--- feature_1 <= 1200025.00
# |   |--- feature_1 <= 534467.00
# |   |   |--- class: LEAVE
# |   |--- feature_1 >  534467.00
# |   |   |--- class: LEAVE
# |--- feature_1 >  1200025.00
# |   |--- class: STAY

# %% [markdown]
# ## Re-Check Accuracy
#
# Is this accuracy better than making a random guess?  (check the distribution above)

# %%
pred = money_tree2.predict(x)

print("Accuracy:",metrics.accuracy_score(y, pred))
# Out:
# Accuracy: 0.6401601067378252

# %% [markdown]
# ## Visualize the model

# %%
from six import StringIO
from IPython.display import Image
import pydotplus

dot_data = StringIO()
export_graphviz(money_tree2, out_file=dot_data,
                   feature_names=x.columns,class_names=['leave','stay'],
                   filled=True,rounded=True, precision =2)

graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# ## Fit a full tree model
#
# Use all of the independent attributes.  We'll call this the "full tree."
#
# What is the accuracy of the full tree?

# %%
# split the datafram into independent (x) and dependent (predicted) attributes (y)
x = df_clean[['income','house','college','data_overage_mb','data_leftover_mb','handset_price','over_15mins_calls_per_month','average_call_duration','reported_satisfaction','reported_usage_level','considering_change_of_plan']]
y = df_clean['leave']

full_tree = DecisionTreeClassifier(criterion="entropy", max_depth=1)

# Create Decision Tree Classifer
full_tree = full_tree.fit(x,y)

# %% [markdown]
# ##Visualize the full tree

# %%
from six import StringIO
from IPython.display import Image
import pydotplus

dot_data = StringIO()
export_graphviz(full_tree, out_file=dot_data,
                   feature_names=x.columns,class_names=['leave','stay'],
                   filled=True,rounded=True, precision =2)

graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# ## Check Accuracy

# %%
pred = full_tree.predict(x)

#print(pred)

print("Accuracy:",metrics.accuracy_score(y, pred))
# Out:
# Accuracy: 0.6401601067378252

# %% [markdown]
# ##Test and Train
# Now we will split the dataset into 80% training data and 20% test data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ##Create a new tree using only training data

# %%
train_tree = DecisionTreeClassifier(criterion="entropy", max_depth=4)

# Create Decision Tree Classifer
train_tree = train_tree.fit(x_train,y_train)

# %% [markdown]
# ##Apply the new tree to our test data

# %%
pred = train_tree.predict(x_test)
print("Accuracy:",metrics.accuracy_score(y_test, pred))
# Out:
# Accuracy: 0.6704469646430954

# %% [markdown]
# ## Visualize the trained tree

# %%
from six import StringIO
from IPython.display import Image
import pydotplus

dot_data = StringIO()
export_graphviz(train_tree, out_file=dot_data,
                   feature_names=x.columns,class_names=['leave','stay'],
                   filled=True,rounded=True, precision =2)

graph=pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# ## Did the model improve?
# 👎  👍

# %% [markdown]
# ## Fine Tune the Tree - Step 1
#
# ➡️ Assignment Tasks
# - Create a new tree object using half the branch depth.
# - Display the accuracy of the new tree.  How does this affect the accuracy?

# %%
#tree 1
#current max_depth of the trained tree
current_max_depth = train_tree.get_depth()
#calculating half the branch depth
new_max_depth = current_max_depth // 2
#created new tree with half the branch depth
new_tree = DecisionTreeClassifier(criterion="entropy", max_depth=new_max_depth)
#trained the new tree
new_tree = new_tree.fit(x_train, y_train)
#predict using the new tree
new_pred = new_tree.predict(x_test)
#calculate and print the accuracy of the new tree
print("Accuracy of the new tree:", metrics.accuracy_score(y_test, new_pred))
# Out:
# Accuracy of the new tree: 0.6420947298198799

# %% [markdown]
# The accuracy is higher than the full tree prediction but lower than the trained tree prediction.

# %% [markdown]
# ## Fine Tune the Tree - Step 2
#
# ➡️ Assignment Tasks
# - Create a new tree object using double the original branch depth.
# - Display the accuracy of the new tree.  How does this affect the accuracy?

# %%
#tree 2
#current max_depth of the trained tree
current_max_depth = train_tree.get_depth()
#calculate double the branch depth
new_max_depth = current_max_depth * 2
#created a new tree with double the branch depth
new_tree2 = DecisionTreeClassifier(criterion="entropy", max_depth=new_max_depth)
#trained the new tree
new_tree2 = new_tree2.fit(x_train, y_train)
#predict using the new tree
new_pred2 = new_tree2.predict(x_test)
#calculate and print the accuracy of the new tree
print("Accuracy of the new tree with double depth:", metrics.accuracy_score(y_test, new_pred2))
# Out:
# Accuracy of the new tree with double depth: 0.6617745163442295

# %% [markdown]
# Just slightly higher accuracy than using the half the branch depth

# %% [markdown]
# ## Fine Tune the Tree - Step 3
#
# ➡️ Assignment Tasks
# - Create a new tree with the maximum depth possible.
# - Display the accuracy of the new tree.  How does this affect the accuracy?

# %%
#tree 3
#create a new tree with the maximum depth possible
new_tree3 = DecisionTreeClassifier(criterion="entropy")
#train the new tree
new_tree3 = new_tree3.fit(x_train, y_train)
#predict using the new tree
new_pred3 = new_tree3.predict(x_test)
#calculate and print the accuracy of the new tree
print("Accuracy of the new tree with maximum depth:", metrics.accuracy_score(y_test, new_pred3))
# Out:
# Accuracy of the new tree with maximum depth: 0.6497665110073382

# %% [markdown]
# this lowered accuracy than when it the branch depth was doubled

# %% [markdown]
# ## Fine Tune the Tree - Step 4
#
# ➡️ Assignment Tasks
# - What is the maximum accuracy that you can achieve with 5 levels using other parameters, like test/training percentage, min_bucket, or min_split?
# - Display the accuracy of the new tree.  It must be more accurate than the previous three steps

# %%
#tree 4
#experiment with different test/train splits, min_samples_split, and min_samples_leaf
best_accuracy = 0
best_params = {}

for test_size in [0.1, 0.2, 0.3]:
  for min_samples_split in [2, 5, 10]:
    for min_samples_leaf in [1, 2, 4]:
      x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=42) #added random_state for reproducibility
      new_tree4 = DecisionTreeClassifier(criterion="entropy", max_depth=5, min_samples_split=min_samples_split, min_samples_leaf=min_samples_leaf)
      new_tree4 = new_tree4.fit(x_train, y_train)
      new_pred4 = new_tree4.predict(x_test)
      accuracy = metrics.accuracy_score(y_test, new_pred4)
      if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_params = {'test_size': test_size, 'min_samples_split': min_samples_split, 'min_samples_leaf': min_samples_leaf}

print(f"Best Accuracy: {best_accuracy}")
print(f"Best Parameters: {best_params}")

#train and evaluate the model with the best parameters
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=best_params['test_size'], random_state=42)
final_tree = DecisionTreeClassifier(criterion="entropy", max_depth=5, min_samples_split=best_params['min_samples_split'], min_samples_leaf=best_params['min_samples_leaf'])
final_tree = final_tree.fit(x_train, y_train)
final_pred = final_tree.predict(x_test)
final_accuracy = metrics.accuracy_score(y_test, final_pred)

print(f"Final Model Accuracy with best parameters: {final_accuracy}")
# Out:
# Best Accuracy: 0.6681120747164776
# Best Parameters: {'test_size': 0.2, 'min_samples_split': 2, 'min_samples_leaf': 1}
# Final Model Accuracy with best parameters: 0.6681120747164776
